# %% [markdown]
# ### Data Wrangling Paper Assignment
# "SDOT_Collisions_All_Years.csv" was downloaded from the following site: <br>
# https://data-seattlecitygis.opendata.arcgis.com/datasets/SeattleCityGIS::sdot-collisions-all-years-2/about

# %%
import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/SDOT_Collisions_All_Years.csv")

# %%
df = pd.read_csv("./data/SDOT_Collisions_All_Years.csv")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19268\2038901166.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/SDOT_Collisions_All_Years.csv")

# %% [markdown]
# #### Basic Operations on the Data

# %%
# Accessing the first 5 rows of the dataframe
df.head()
# Out:
#    OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 0   6700659    System.Byte[]  365797     367277  ED63058    Matched
# 1   6700660    System.Byte[]  366565     368045  ED67817    Matched
# 2   6700661    System.Byte[]  366061     367541  3898239  Unmatched
# 3   6700662    System.Byte[]  367039     368519  EE16272    Matched
# 4   6700663    System.Byte[]  366650     368130  3916400    Matched
#
#        ADDRTYPE   INTKEY                                           LOCATION  \
# 0         Block      NaN               2ND AVE BETWEEN UNION ST AND PIKE ST
# 1         Block      NaN  17TH AVE S BETWEEN S STEVENS ST AND S WINTHROP ST
# 2  Intersection  36586.0                    1ST AVE NE AND NE NORTHGATE WAY
# 3  Intersection  29914.0                          6TH AVE AND UNIVERSITY ST
# 4         Block      NaN  WEST SEATTLE BR WB BETWEEN POINT A AND 35TH AV...
#
#   EXCEPTRSNCODE  ... HITPARKEDCAR    SPDCASENO Source of the collision report  \
# ...

# %%
df.tail()
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 248320   6948979    System.Byte[]  365701     367181  3916757  Matched
# 248321   6948980    System.Byte[]  363615     365095  ED79889  Matched
# 248322   6948981    System.Byte[]  364469     365949  ED84432  Matched
# 248323   6948982    System.Byte[]  365161     366641  ED98257  Matched
# 248324   6948983    System.Byte[]  364748     366228  ED92249  Matched
#
#             ADDRTYPE   INTKEY  \
# 248320         Block      NaN
# 248321  Intersection  33471.0
# 248322  Intersection  25690.0
# 248323         Block      NaN
# 248324         Block      NaN
#
#                                                  LOCATION EXCEPTRSNCODE  ...  \
# 248320  SW SPOKANE ST BETWEEN S SPOKANE ST AND SW KLIC...           NaN  ...
# 248321                       42ND AVE S AND RAINIER AVE S           NaN  ...
# 248322                         LINDEN AVE N AND N 46TH ST           NaN  ...
# ...

# %%
#Retrieving all the column names of the dat
df.columns
# Out:
# Index(['OBJECTID', 'SE_ANNO_CAD_DATA', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES',
#        'SERIOUSINJURIES', 'FATALITIES', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE',
#        'SDOT_COLCODE', 'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL',
#        'WEATHER', 'ROADCOND', 'LIGHTCOND', 'DIAGRAMLINK', 'REPORTLINK',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'STCOLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR', 'SPDCASENO',
#        'Source of the collision report', 'Source description', 'Added by User',
#        'Added date', 'Modified by', 'Modified date', 'x', 'y'],
#       dtype='object')

# %%
#The shape of the data
df.shape
# Out:
# (248325, 50)

# %%
#getting the info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248325 entries, 0 to 248324
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   OBJECTID                        248325 non-null  int64
#  1   SE_ANNO_CAD_DATA                248325 non-null  object
#  2   INCKEY                          248325 non-null  int64
#  3   COLDETKEY                       248325 non-null  int64
#  4   REPORTNO                        248325 non-null  object
#  5   STATUS                          248325 non-null  object
#  6   ADDRTYPE                        244389 non-null  object
#  7   INTKEY                          82833 non-null   float64
#  8   LOCATION                        243451 non-null  object
#  9   EXCEPTRSNCODE                   12795 non-null   object
#  10  EXCEPTRSNDESC                   12795 non-null   object
#  11  SEVERITYCODE                    248324 non-null  object
# ...

# %%
#Descriptive Statistics
#Getting the Mean, median, mode, quartiles, range, standard deviation of the data
df.describe()
# Out:
#            OBJECTID         INCKEY      COLDETKEY         INTKEY  \
# count  2.483250e+05  248325.000000  248325.000000   82833.000000
# mean   6.824821e+06  167186.098717  167550.496474   38205.053735
# std    7.168540e+04  106055.143200  106572.942551   54466.982259
# min    6.700659e+06    1001.000000    1001.000000   23807.000000
# 25%    6.762740e+06   78370.000000   78370.000000   28667.000000
# 50%    6.824821e+06  140844.000000  140844.000000   30102.000000
# 75%    6.886902e+06  244873.000000  245473.000000   34082.000000
# max    6.948983e+06  371245.000000  372725.000000  858453.000000
#
#          PERSONCOUNT       PEDCOUNT    PEDCYLCOUNT       VEHCOUNT  \
# count  248325.000000  248325.000000  248325.000000  248325.000000
# mean        2.237060       0.038880       0.027810       1.695504
# std         1.442166       0.203697       0.165892       0.862173
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# #### Basic Query Operations

# %%
#Getting the 6th row of the dataframe
df.iloc[5]
# Out:
# OBJECTID                                                                    6700664
# SE_ANNO_CAD_DATA                                                      System.Byte[]
# INCKEY                                                                       366082
# COLDETKEY                                                                    367562
# REPORTNO                                                                    ED66441
# STATUS                                                                      Matched
# ADDRTYPE                                                               Intersection
# INTKEY                                                                      29736.0
# LOCATION                                                     BROADWAY AND E PINE ST
# EXCEPTRSNCODE                                                                   NaN
# EXCEPTRSNDESC                                                                   NaN
# ...

# %%
# Selecting multiple colums: SEVERITYDESC, COLLISIONTYPE, PERSONCOUNT
df[['SEVERITYDESC', 'COLLISIONTYPE', 'PERSONCOUNT']]
# Out:
#                           SEVERITYDESC COLLISIONTYPE  PERSONCOUNT
# 0                     Injury Collision    Pedestrian            2
# 1       Property Damage Only Collision    Parked Car            3
# 2       Property Damage Only Collision           NaN            1
# 3             Serious Injury Collision        Cycles            2
# 4       Property Damage Only Collision         Other            1
# ...                                ...           ...          ...
# 248320                Injury Collision         Other            2
# 248321  Property Damage Only Collision        Angles            2
# 248322                Injury Collision    Rear Ended            7
# 248323  Property Damage Only Collision    Parked Car            2
# 248324  Property Damage Only Collision     Sideswipe            3
#
# [248325 rows x 3 columns]

# %% [markdown]
# It shows the objectid, reportno, severity description and the type of the collision slicing the rows from index 10 to 14.

# %%
df[['OBJECTID', 'REPORTNO', 'SEVERITYDESC', 'COLLISIONTYPE']][10:15]
# Out:
#     OBJECTID REPORTNO                    SEVERITYDESC COLLISIONTYPE
# 10   6700669  3903203  Property Damage Only Collision         Other
# 11   6700670  3899736  Property Damage Only Collision    Parked Car
# 12   6700671  3894494  Property Damage Only Collision           NaN
# 13   6700672  3904313                Injury Collision    Rear Ended
# 14   6700673  3919239  Property Damage Only Collision         Other

# %% [markdown]
# Showing the report number and location accidents happened at rainy day, at day time where only physical damage to property has occured, without any injuries to individuals involved in the collision. Also, it includes reports of vehicle collisions submitted by citizens.

# %%
df.loc[(df['SEVERITYDESC'] == 'Property Damage Only Collision') & (df['WEATHER'] == 'Raining') & (df['LIGHTCOND'] == 'Daylight') & (df['Source description'] == 'Citizen Vehicle Collision Report'), ['REPORTNO', 'LOCATION']]
# Out:
#        REPORTNO                                           LOCATION
# 130261  3643888                                                NaN
# 151832  3700655    S FARRAR ST BETWEEN WILSON AVE S AND 51ST AVE S
# 152298  3590733          CHERRY ST BETWEEN BOREN AVE AND MINOR AVE
# 153003  3732714        3RD AVE N BETWEEN CROCKETT ST AND BOSTON ST
# 153937  3590734  QUEEN ANNE AVE N BETWEEN W GALER ST AND GARFIE...
# ...         ...                                                ...
# 235316  EC43641                              20TH AVE AND E FIR ST
# 235376  3890364      BOYER AVE E BETWEEN 25TH AVE E AND 24TH AVE E
# 236913  3899860             7TH AVE BETWEEN JAMES ST AND CHERRY ST
# 242422  3896204  RAINIER AVE S BETWEEN S MORGAN ST AND S WARSAW ST
# 246140  ED51355  48TH AVE SW BETWEEN SW RAYMOND ST AND SW GRAHA...
#
# [76 rows x 2 columns]

# %% [markdown]
# Getting the user name, i.e column ADDED BY USER

# %%
df.iloc[:, -6]
# Out:
# 0         JOHNSOS1
# 1         ZUNIGAR1
# 2          RAUSCHE
# 3         ZUNIGAR1
# 4          RAUSCHE
#             ...
# 248320     RAUSCHE
# 248321       WADEC
# 248322    JOHNSOS1
# 248323       WADEC
# 248324     ABAYNEH
# Name: Added by User, Length: 248325, dtype: object

# %% [markdown]
# Selecting all the matched report with injuries greater than 10

# %%
df.loc[(df['STATUS'] == 'Matched') & (df['INJURIES'] > 10)]
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 582      6701241    System.Byte[]  366835     368315  3913831  Matched
# 25842    6726501    System.Byte[]   37216      37216  1792747  Matched
# 61116    6761775    System.Byte[]   74597      74597  2898228  Matched
# 69264    6769923    System.Byte[]   81084      81084  2898105  Matched
# 96428    6797087    System.Byte[]  108948     108948  3208143  Matched
# 131113   6831772    System.Byte[]  145917     145937  3573476  Matched
# 153727   6854386    System.Byte[]  179717     179777  2796051  Matched
# 153784   6854443    System.Byte[]  181413     181453  3644629  Matched
# 163605   6864264    System.Byte[]  198091     198219  3738954  Matched
# 165431   6866090    System.Byte[]  203057     203197  3703661  Matched
# 188697   6889356    System.Byte[]  245584     246184  E687975  Matched
# 248050   6948709    System.Byte[]  365099     366579  3919386  Matched
#
#             ADDRTYPE   INTKEY  \
# ...

# %% [markdown]
# #### Cleaning data

# %% [markdown]
# Checking duplicate entries

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [OBJECTID, SE_ANNO_CAD_DATA, INCKEY, COLDETKEY, REPORTNO, STATUS, ADDRTYPE, INTKEY, LOCATION, EXCEPTRSNCODE, EXCEPTRSNDESC, SEVERITYCODE, SEVERITYDESC, COLLISIONTYPE, PERSONCOUNT, PEDCOUNT, PEDCYLCOUNT, VEHCOUNT, INJURIES, SERIOUSINJURIES, FATALITIES, INCDATE, INCDTTM, JUNCTIONTYPE, SDOT_COLCODE, SDOT_COLDESC, INATTENTIONIND, UNDERINFL, WEATHER, ROADCOND, LIGHTCOND, DIAGRAMLINK, REPORTLINK, PEDROWNOTGRNT, SDOTCOLNUM, SPEEDING, STCOLCODE, ST_COLDESC, SEGLANEKEY, CROSSWALKKEY, HITPARKEDCAR, SPDCASENO, Source of the collision report, Source description, Added by User, Added date, Modified by, Modified date, x, y]
# Index: []
#
# [0 rows x 50 columns]

# %% [markdown]
# Thus, there are no duplicated entries, now lets check the missing values

# %%
df.isnull().sum()
# Out:
# OBJECTID                               0
# SE_ANNO_CAD_DATA                       0
# INCKEY                                 0
# COLDETKEY                              0
# REPORTNO                               0
# STATUS                                 0
# ADDRTYPE                            3936
# INTKEY                            165492
# LOCATION                            4874
# EXCEPTRSNCODE                     235530
# EXCEPTRSNDESC                     235530
# SEVERITYCODE                           1
# SEVERITYDESC                           0
# COLLISIONTYPE                      33685
# PERSONCOUNT                            0
# PEDCOUNT                               0
# PEDCYLCOUNT                            0
# VEHCOUNT                               0
# INJURIES                               0
# SERIOUSINJURIES                        0
# FATALITIES                             0
# INCDATE                                0
# INCDTTM                                0
# ...

# %%
#Removing all the missing data
cleaned_df = df.dropna()
cleaned_df
# Out:
# Empty DataFrame
# Columns: [OBJECTID, SE_ANNO_CAD_DATA, INCKEY, COLDETKEY, REPORTNO, STATUS, ADDRTYPE, INTKEY, LOCATION, EXCEPTRSNCODE, EXCEPTRSNDESC, SEVERITYCODE, SEVERITYDESC, COLLISIONTYPE, PERSONCOUNT, PEDCOUNT, PEDCYLCOUNT, VEHCOUNT, INJURIES, SERIOUSINJURIES, FATALITIES, INCDATE, INCDTTM, JUNCTIONTYPE, SDOT_COLCODE, SDOT_COLDESC, INATTENTIONIND, UNDERINFL, WEATHER, ROADCOND, LIGHTCOND, DIAGRAMLINK, REPORTLINK, PEDROWNOTGRNT, SDOTCOLNUM, SPEEDING, STCOLCODE, ST_COLDESC, SEGLANEKEY, CROSSWALKKEY, HITPARKEDCAR, SPDCASENO, Source of the collision report, Source description, Added by User, Added date, Modified by, Modified date, x, y]
# Index: []
#
# [0 rows x 50 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Visualizing the missing data by using heat maps:

# %%
sns.heatmap(df.isnull(), cmap = 'hot')
# Out:
# <Axes: >

# %%
cleandf = df

# %% [markdown]
# Finding the columns that has greater null values

# %%
null_data = cleandf.isnull().sum() / len(cleandf) *100
columns_to_drop = null_data[null_data>50].index
columns_to_drop
# Out:
# Index(['INTKEY', 'EXCEPTRSNCODE', 'EXCEPTRSNDESC', 'INATTENTIONIND',
#        'PEDROWNOTGRNT', 'SPEEDING'],
#       dtype='object')

# %% [markdown]
# INATTENTIONIND and SPEEDING seems important features, so let's not drop them.
# <br>
# Additionally, few other columns can be dropped.

# %%
columns_to_drop = list(columns_to_drop)
columns_to_drop.remove('SPEEDING')
columns_to_drop.remove('INATTENTIONIND')
columns_to_drop
# Out:
# ['INTKEY', 'EXCEPTRSNCODE', 'EXCEPTRSNDESC', 'PEDROWNOTGRNT']

# %%
other_drops = ['Source description', 'Added by User','Added date', 'Modified by', 'Modified date', 'x', 'y', 'INCDATE', 'INCDTTM', 'SPDCASENO', 'SE_ANNO_CAD_DATA', 'SDOTCOLNUM']
columns_to_drop = columns_to_drop + other_drops
columns_to_drop
# Out:
# ['INTKEY',
#  'EXCEPTRSNCODE',
#  'EXCEPTRSNDESC',
#  'PEDROWNOTGRNT',
#  'Source description',
#  'Added by User',
#  'Added date',
#  'Modified by',
#  'Modified date',
#  'x',
#  'y',
#  'INCDATE',
#  'INCDTTM',
#  'SPDCASENO',
#  'SE_ANNO_CAD_DATA',
#  'SDOTCOLNUM']

# %%
cleandf = cleandf.drop(columns_to_drop, axis = 1)
#Dropping all the columns in the list columns_to_drop

# %%
cleandf.columns
# Out:
# Index(['OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO', 'STATUS', 'ADDRTYPE',
#        'LOCATION', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES',
#        'SERIOUSINJURIES', 'FATALITIES', 'JUNCTIONTYPE', 'SDOT_COLCODE',
#        'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND',
#        'LIGHTCOND', 'DIAGRAMLINK', 'REPORTLINK', 'SPEEDING', 'STCOLCODE',
#        'ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR',
#        'Source of the collision report'],
#       dtype='object')

# %%
cleandf['SPEEDING'] = cleandf['SPEEDING'].fillna('N')
cleandf['INATTENTIONIND'] = cleandf['INATTENTIONIND'].fillna('N')

# %%
numeric_columns = cleandf.select_dtypes(include='number')
categorical_columns = cleandf.select_dtypes(include=['object', 'string'])

# %%
print(cleandf.columns)
print('Numeric: ',numeric_columns.columns)
print('Categorical: ', categorical_columns.columns)
# Out:
# Index(['OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO', 'STATUS', 'ADDRTYPE',
#        'LOCATION', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES',
#        'SERIOUSINJURIES', 'FATALITIES', 'JUNCTIONTYPE', 'SDOT_COLCODE',
#        'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND',
#        'LIGHTCOND', 'DIAGRAMLINK', 'REPORTLINK', 'SPEEDING', 'STCOLCODE',
#        'ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR',
#        'Source of the collision report'],
#       dtype='object')
# Numeric:  Index(['OBJECTID', 'INCKEY', 'COLDETKEY', 'PERSONCOUNT', 'PEDCOUNT',
#        'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES',
#        'SDOT_COLCODE', 'STCOLCODE', 'SEGLANEKEY', 'CROSSWALKKEY'],
#       dtype='object')
# Categorical:  Index(['REPORTNO', 'STATUS', 'ADDRTYPE', 'LOCATION', 'SEVERITYCODE',
# ...

# %%
newcategorical_columns = categorical_columns.drop(['REPORTNO','STATUS', 'ADDRTYPE', 'LOCATION', 'DIAGRAMLINK', 'REPORTLINK', 'ST_COLDESC','SDOT_COLDESC' ], axis = 1)

# %%
newcategorical_columns.columns
# Out:
# Index(['SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE', 'JUNCTIONTYPE',
#        'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'SPEEDING', 'HITPARKEDCAR', 'Source of the collision report'],
#       dtype='object')

# %% [markdown]
# Removing the rows with null values for other columns

# %%
cleandf = cleandf[~cleandf['SEVERITYCODE'].isnull() & (cleandf['SEVERITYDESC'] != 'Unknown')]

# %%
cleandf = cleandf[~cleandf['WEATHER'].isnull() & ~cleandf['ROADCOND'].isnull() & ~cleandf['LIGHTCOND'].isnull() & ~cleandf['COLLISIONTYPE'].isnull() & ~cleandf['LOCATION'].isnull() ]

# %%
cleandf = cleandf[~cleandf['JUNCTIONTYPE'].isnull()]

# %%
cleandf.isnull().sum()
# Out:
# OBJECTID                          0
# INCKEY                            0
# COLDETKEY                         0
# REPORTNO                          0
# STATUS                            0
# ADDRTYPE                          0
# LOCATION                          0
# SEVERITYCODE                      0
# SEVERITYDESC                      0
# COLLISIONTYPE                     0
# PERSONCOUNT                       0
# PEDCOUNT                          0
# PEDCYLCOUNT                       0
# VEHCOUNT                          0
# INJURIES                          0
# SERIOUSINJURIES                   0
# FATALITIES                        0
# JUNCTIONTYPE                      0
# SDOT_COLCODE                      0
# SDOT_COLDESC                      0
# INATTENTIONIND                    0
# UNDERINFL                         0
# WEATHER                           0
# ROADCOND                          0
# LIGHTCOND                         0
# DIAGRAMLINK                       0
# ...

# %%
sns.heatmap(cleandf.isnull(), cmap = 'hot')
# Out:
# <Axes: >

# %% [markdown]
# #### Explorative Data Analysis
# - Univariate Analysis: Studying one variable at a time
# - Bivariate Analysis: Studying two variables at a time
# - Multivariate Analysis: Studying multiple variables at a time
# - Investigate each feature properly

# %% [markdown]
# #### Univariate Analysis

# %%
#Showing the categories of severity desc in piechart
severity_counts = df['SEVERITYDESC'].value_counts()
plt.figure(figsize=(10, 8))
plt.pie(severity_counts, labels=severity_counts.index)
plt.legend()
plt.show()

# %%
def plot_univariate_analysis_numeric(df):
  for column in numeric_columns:
    plt.figure(figsize=(10, 4))
    # Histogram
    plt.subplot(1, 3, 1)
    sns.histplot(cleandf[column])
    plt.title(f'{column} Histogram')

    # Distribution 
    plt.subplot(1, 3, 2)
    sns.kdeplot(cleandf[column])
    plt.title(f'{column} Distribution')

    # Boxplot
    plt.subplot(1, 3, 3)  
    sns.boxplot(x=cleandf[column])
    plt.title(f'{column} Boxplot')

    plt.tight_layout()
    plt.show()

# %%
plot_univariate_analysis_numeric(numeric_columns)

# %%
def plot_univariate_analysis_categorical(df):
    columns = df.columns
    
    for column in columns:
      #bar plot
      plt.figure(figsize=(5,3))
      sns.countplot(data=df, x=column)
      plt.title(f'Count Plot of {column}')
      plt.xlabel(column)
      plt.ylabel('Count')
      plt.xticks(rotation=45)
      plt.tight_layout()
      plt.show()
      
      #Pie chart
      plt.figure(figsize=(8,8))
      df[column].value_counts().plot.pie(autopct='%1.1f%%', fontsize=6)
      plt.title(f'Pie Chart of {column}')
      plt.legend(fontsize='small')
      plt.tight_layout()
      plt.show()

# %%
plot_univariate_analysis_categorical(newcategorical_columns)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19268\2870387678.py:12: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
collision = cleandf[['HITPARKEDCAR', 'COLLISIONTYPE', 'PERSONCOUNT']].value_counts().reset_index(name='Count')

# %%
#Relationship between collision type and personcount
plt.figure(figsize = (12, 8))
sns.barplot(x='COLLISIONTYPE', y='PERSONCOUNT', hue='HITPARKEDCAR', data=collision)
plt.title('Barplot for showing relationship between collision and personcount')
plt.show()

# %%
#Relationship between speeding and injuries
speeding = cleandf[['SPEEDING', 'SERIOUSINJURIES', 'PERSONCOUNT']].value_counts().reset_index(name='Count')
plt.figure(figsize = (12, 8))
sns.barplot(x='SERIOUSINJURIES', y='PERSONCOUNT', hue='SPEEDING', data=speeding)
plt.title('Barplot for showing relationship between speeding and injuries')
plt.show()

# %%
#Relationship between vehicle and collision
collision_veh = cleandf[['COLLISIONTYPE', 'VEHCOUNT', 'INATTENTIONIND']].value_counts().reset_index(name='Count')
plt.figure(figsize = (12, 8))
sns.barplot(x='COLLISIONTYPE', y='VEHCOUNT', hue='INATTENTIONIND', data=collision_veh)
plt.title('Grouped barplot for showing relationship between collision and vehicle')
plt.show()

# %% [markdown]
# #### Bivariate and Multivariate Analysis

# %%
target_column = 'SEVERITYDESC'
reqd_cols = ['SEVERITYCODE', 'COLLISIONTYPE', 'ROADCOND', 'LIGHTCOND', 'SPEEDING', 'HITPARKEDCAR']
for column in reqd_cols:
    plt.figure(figsize=(12, 6))

    # Grouped bar plot
    plt.subplot(1, 2, 2)
    sns.countplot(data=df, x=column, hue=target_column)
    plt.title(f'Grouped Bar Plot of {column} vs {target_column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

    plt.tight_layout()
    plt.show()

# %%
#Now observing through scatter plot
# injuries and vehicle
sns.scatterplot(data=cleandf, x='VEHCOUNT', y='INJURIES')
# Out:
# <Axes: xlabel='VEHCOUNT', ylabel='INJURIES'>

# %%
# injuries and personcount
sns.scatterplot(data=cleandf, x='PERSONCOUNT', y='INJURIES')
# Out:
# <Axes: xlabel='PERSONCOUNT', ylabel='INJURIES'>

# %%
sns.pairplot(cleandf, vars=['INJURIES', 'PERSONCOUNT'], hue='SEVERITYDESC')

# %%
# Scatterplot analysis beteen fatalities and injuries
plt.figure(figsize = (12, 8))
sns.scatterplot(data = cleandf , x = 'INJURIES', y = 'SERIOUSINJURIES', hue = 'SEVERITYCODE')
plt.title('Relationship betweeen injuries, fatalities and severity code')
plt.show()

# %%
plt.figure(figsize= (12, 8))
sns.heatmap(cleandf.select_dtypes('number').corr(), cmap = 'cool',
            annot = True)
plt.show()

# %% [markdown]
# Here the correlation coefficient closer to 0 indicates strong non-linear relationship where as the strong linear relationship is indicated by a correlation coefficient close to -1 (strong negative linear relationship) or 1 (strong positive linear relationship).

# %% [markdown]
# #### Hypothesis Testing

# %%
from scipy.stats import chi2_contingency
from scipy.stats import kstest, shapiro

# %%
# Chi-Square Test 
def chi_square_test(df, columns, target):

    for column in columns:
        crosstab = pd.crosstab(df[target], df[column])
        chi2, p, dof, expected = chi2_contingency(crosstab)
        print(f'Chi-Square Test for {column} and {target}')
        print(f'Chi2: {chi2}')
        print(f'P-Value: {p}')
        print(f'Degrees of Freedom: {dof}')

        if p < 0.05:
            print(f'Reject Null Hypothesis :: There is a strong relationship between severity and {column} \n')
        else:
            print(f'Fail to Reject Null Hypothesis :: There is no relationship between severity and {column} \n')

# %%
chi_square_test(cleandf, reqd_cols, target_column)
# Out:
# Chi-Square Test for SEVERITYCODE and SEVERITYDESC
# Chi2: 621351.0
# P-Value: 0.0
# Degrees of Freedom: 9
# Reject Null Hypothesis :: There is a strong relationship between severity and SEVERITYCODE
#
# Chi-Square Test for COLLISIONTYPE and SEVERITYDESC
# Chi2: 49553.00519363732
# P-Value: 0.0
# Degrees of Freedom: 27
# Reject Null Hypothesis :: There is a strong relationship between severity and COLLISIONTYPE
#
# Chi-Square Test for ROADCOND and SEVERITYDESC
# Chi2: 4156.222110169551
# P-Value: 0.0
# Degrees of Freedom: 24
# Reject Null Hypothesis :: There is a strong relationship between severity and ROADCOND
#
# Chi-Square Test for LIGHTCOND and SEVERITYDESC
# Chi2: 4265.069369736889
# P-Value: 0.0
# Degrees of Freedom: 24
# Reject Null Hypothesis :: There is a strong relationship between severity and LIGHTCOND
#
# Chi-Square Test for SPEEDING and SEVERITYDESC
# Chi2: 954.9467910185218
# P-Value: 1.067389176778909e-206
# Degrees of Freedom: 3
# ...

# %%
def normality_test(data, alpha=0.05):
    statistic, pvalue = kstest(data, 'norm')
    print("Kolmogorov-Smirnov Test Statistic:", statistic)
    print('p-value:', pvalue)
    if pvalue > alpha:
        print("Sample looks Gaussian (fail to reject H0)")
    else:
        print("Sample does not look Gaussian (reject H0)")

for column in numeric_columns:
    print(f'Normality Test for {column}')
    normality_test(cleandf[column])
# Out:
# Normality Test for OBJECTID
# Kolmogorov-Smirnov Test Statistic: 1.0
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for INCKEY
# Kolmogorov-Smirnov Test Statistic: 1.0
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for COLDETKEY
# Kolmogorov-Smirnov Test Statistic: 1.0
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for PERSONCOUNT
# Kolmogorov-Smirnov Test Statistic: 0.8945236794724188
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for PEDCOUNT
# Kolmogorov-Smirnov Test Statistic: 0.5
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for PEDCYLCOUNT
# Kolmogorov-Smirnov Test Statistic: 0.5
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for VEHCOUNT
# Kolmogorov-Smirnov Test Statistic: 0.8401425270329254
# p-value: 0.0
# Sample does not look Gaussian (reject H0)
# Normality Test for INJURIES
# ...

# %%
sample = cleandf.sample(n=1000)

def shapiro_wilk_test(data, alpha = 0.05):
    
    statistic, pvalue = shapiro(data)
    print("Shapiro-Wilk Test Statistic:", statistic)
    print('p-value', pvalue)
    if pvalue > alpha: print("Sample looks Gaussian (fail to reject H0) \n")

    else: print("Sample does not look Gaussian (reject H0) \n")

for column in numeric_columns:
    print(f'Shapiro-Wilk Test for {column}')
    shapiro_wilk_test(sample[column])
# Out:
# Shapiro-Wilk Test for OBJECTID
# Shapiro-Wilk Test Statistic: 0.9604116700020804
# p-value 8.056253172296404e-16
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for INCKEY
# Shapiro-Wilk Test Statistic: 0.9252484985297122
# p-value 6.99145082730046e-22
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for COLDETKEY
# Shapiro-Wilk Test Statistic: 0.9244750224058126
# p-value 5.465716847981687e-22
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for PERSONCOUNT
# Shapiro-Wilk Test Statistic: 0.7915756613298937
# p-value 6.611017088443045e-34
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for PEDCOUNT
# Shapiro-Wilk Test Statistic: 0.21937025154301049
# p-value 1.724815739278851e-53
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for PEDCYLCOUNT
# Shapiro-Wilk Test Statistic: 0.1659453133154749
# p-value 1.3594317212015984e-54
# Sample does not look Gaussian (reject H0)
#
# ...
